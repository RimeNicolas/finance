# %%
import mod1
import importlib
importlib.reload(mod1)

import numpy as np
import matplotlib.pyplot as plt

# %%
list_tickers = [
        'MSFT',
        'AAPL',
        'SPY'
    ]
dict_ticker = mod1.create_dict_tickers(list_tickers)
period = '6mo'
hist = dict_ticker['AAPL'].history(period)
aa = np.array(sorted(hist['Open'].pct_change()[1:]))

# %%
plt.hist(aa, bins=50)
plt.show()

# %%
alpha = 0.05
q_np = np.quantile(aa, alpha) # unit var non-parametric

# %%
es_np = np.mean(aa[:int(0.05*len(aa))])

# %%
from scipy.stats import t
params = t.fit(aa)
x = np.linspace(aa[0], aa[-1], 100)
plt.figure(1)
plt.plot(x, t.pdf(x, params[0], params[1], params[2]))
plt.hist(aa, bins=50)
plt.show()
