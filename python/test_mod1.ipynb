# %%
import mod1
import importlib
importlib.reload(mod1)

import numpy as np
import matplotlib.pyplot as plt

# %%
list_tickers = [
        'MSFT',
        'AAPL',
        'SPY'
    ]

# %%
dict_ticker = mod1.create_dict_tickers(list_tickers)

# %%
period = '3y'

plt.figure(1)
for tick in list_tickers:
    hist = dict_ticker[tick].history(period)
    plt.plot(hist.index, hist['Open'].values)
    print(tick)
plt.legend(list_tickers)
plt.show()
# Out:
# MSFT
# AAPL
# SPY

# %%
hist = dict_ticker['AAPL'].history('3y')

# %%
aapl_open_price = np.array(hist['Open'].values)

# %%
aapl_daily_return = np.copy(aapl_open_price)
for i in range(1, len(aapl_open_price)):
    aapl_daily_return[i] -= aapl_open_price[i-1]
aapl_daily_return = aapl_daily_return[1:]

plt.hist(aapl_daily_return)
print(np.mean(aapl_daily_return))
print(np.std(aapl_daily_return))
plt.show()
# Out:
# 0.22066401062417001
# 4.17383598901619

# %%
aa = hist['Open'].pct_change()[1:]

# %%
plt.hist(aa)
plt.show()
